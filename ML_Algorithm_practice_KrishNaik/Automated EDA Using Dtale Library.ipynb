# %% [markdown]
# # Automated EDA Using Dtale Library

# %%
pip install dtale
# Out:
# ...
#      |████████████████████████████████| 14.7 MB 453 kB/s eta 0:00:01    |█▊                              | 788 kB 878 kB/s eta 0:00:16     |███▋                            | 1.6 MB 1.5 MB/s eta 0:00:09     |█████████▏                      | 4.2 MB 399 kB/s eta 0:00:27     |███████████████▎                | 7.0 MB 762 kB/s eta 0:00:11     |███████████████████             | 8.7 MB 491 kB/s eta 0:00:13     |█████████████████████████▋      | 11.8 MB 293 kB/s eta 0:00:10     |████████████████████████████    | 12.9 MB 258 kB/s eta 0:00:07     |████████████████████████████▊   | 13.2 MB 258 kB/s eta 0:00:06
# ...
#      |████████████████████████████████| 62 kB 431 kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 222 kB 1.5 MB/s eta 0:00:01
# ...
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# ...
#      |████████████████████████████████| 973 kB 131 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 642 kB 1.3 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import dtale
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://zec-HP-EliteBook-840-G3:40000/dtale/iframe/5"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# 2025-01-11 22:00:55,834 - ERROR    - Exception on /dtale/static/fonts/istok.woff [GET]
# Traceback (most recent call last):
#   File "/home/zec/.local/lib/python3.8/site-packages/flask/app.py", line 2077, in wsgi_app
#   File "/home/zec/.local/lib/python3.8/site-packages/flask/app.py", line 1525, in full_dispatch_request
#   File "/home/zec/.local/lib/python3.8/site-packages/flask/app.py", line 1523, in full_dispatch_request
#   File "/home/zec/.local/lib/python3.8/site-packages/flask/app.py", line 1509, in dispatch_request
#   File "/home/zec/.local/lib/python3.8/site-packages/flask/app.py", line 515, in <lambda>
#     **options: t.Any,
#   File "/home/zec/.local/lib/python3.8/site-packages/flask/scaffold.py", line 328, in send_static_file
# ...
